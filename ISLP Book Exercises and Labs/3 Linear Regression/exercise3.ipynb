# %% [markdown]
# # <span style="color: rgb(0, 105, 175);">Exercise Solutions:</span>

# %% [markdown]
# ## <span style="color: rgb(0, 105, 175);">*Conceptual*</span>

# %% [markdown]
# ### Q1

# %% [markdown]
# #### $\text{ 1. Describe the null hypotheses to which the p-values given in Table 3.4 correspond. Explain what conclusions you can draw \\ based on these p-values. Your explanation should be phrased in terms of \textcolor{145, 75, 40}{sales}, \textcolor{145, 75, 40}{TV}, \textcolor{145, 75, 40}{radio}, and \textcolor{145, 75, 40}{newspaper}, rather than in \\ terms of the coefficients of the linear model. }$
#
# ![Data Set](e1.png)

# %% [markdown]
# #### $\text{}$ $\text{Null Hypotheses for Each Parameter:}$
#
# 1. **$\text{TV Advertising Budget (Parameter: TV)}$**:
#    - **$\text{Null Hypothesis (H₀)}$**$\text{: The TV advertising budget does not significantly affect sales.}$
#      - $\text{Mathematically: H₀: β₁ = 0 (TV has no effect on sales)}$
#
# 2. **$\text{Radio Advertising Budget (Parameter: Radio)}$**:
#    - **$\text{Null Hypothesis (H₀)}$**$\text{: The radio advertising budget does not significantly affect sales.}$
#      - $\text{Mathematically: H₀: β₂ = 0 (Radio has no effect on sales)}$
#
# 3. **$\text{Newspaper Advertising Budget (Parameter: Newspaper)}$**:
#    - **$\text{Null Hypothesis (H₀)}$**$\text{: The newspaper advertising budget does not significantly affect sales.}$
#      - $\text{Mathematically: H₀: β₂ = 0 (Mathematically: H₀: β₃ = 0 (Newspaper has no effect on sales)}$
#
# ---
#
# #### $\text{}$ $\text{General Null Hypothesis for the Model:}$
# $\text{If you're testing whether any of these parameters (TV, radio, or newspaper) collectively explain sales, the overall null hypothesis can be stated as:}$
#
# - **$\text{Null Hypothesis (H₀)}$**: $\text{Sales cannot be explained by TV, radio, and newspaper advertising budgets (None of the coefficients are significantly different from zero).}$
#   - $\text{This would be: H₀: β₁ = β₂ = β₃ = 0 (No effect from any of the parameters)}$
#
# ---
#
# #### $\text{}$ $\text{Conclusion Based on the p-values:}$
#
# - **$\text{TV Advertising Budget (Parameter: TV)}$**:
#   - **$\text{p-value < 0.0001}$**$\text{: The TV advertising budget **does** significantly affect sales.}$
#   - ** $\text{Conclusion}$**$\text{: Reject the null hypothesis for TV.}$
#
# - **$\text{Radio Advertising Budget (Parameter: Radio)}$**:
#   - **$\text{p-value < 0.0001}$**$\text{: The radio advertising budget **does** significantly affect sales.}$
#   - **$\text{Conclusion}$**$\text{: Reject the null hypothesis for radio.}$
#
# - **$\text{$Newspaper Advertising Budget (Parameter: Newspaper)}**:
#   - **$\text{p-value = 0.8599}$**$\text{: The newspaper advertising budget **does not** significantly affect sales.}$
#   - **$\text{Conclusion}$**$\text{: Fail to reject the null hypothesis for newspaper.}$
#
# ---
#
# #### $\text{Final Recommendation:}$
#
# $\text{ Since TV and radio advertising budgets have a significant impact on sales, but newspaper does not, you may want to focus on TV and radio when \\ analyzing factors affecting sales. If the parameters are independent, it might be more accurate to analyze them separately for more specific insights.}$

# %% [markdown]
# ### Q2

# %% [markdown]
# #### $\text{2. Carefully explain the differences between the KNN classifier and KNN regression methods.}$

# %% [markdown]
# #### $\text{}$$\text{Differences Between KNN Classifier and KNN Regression Methods}$
#
# $\text{ KNN (K-Nearest Neighbors) is a versatile algorithm that can be used for both classification and regression tasks. While the underlying mechanism of \\ KNN is similar in both cases, the key differences arise in how the predictions are made.}$
#
# ---
#
# ##### 1. $\textbf{Problem Type:}$
#    - **$\text{KNN Classifier}$**:
#      - $\text{Used for}$ $\textbf{classification tasks}$$\text{, where the goal is to assign a class label to an input based on the majority class of its nearest neighbors.}$
#      - $\text{Example: Classifying an email as "spam" or "not spam."}$
#
#    - **$\text{KNN Regression}$**:
#      - $\text{Used for }$$\textbf{regression tasks}$$\text{, where the goal is to predict a continuous value based on the average of the values of the nearest neighbors.}$
#
#      - $\text{Example: Predicting the price of a house based on its features (e.g., size, location).}$
#
# ---
#
# ##### $\text{2. }$$\textbf{Prediction Method:}$
#    - **$\text{KNN Classifier}$**:
#      - $\text{For a given input, the KNN classifier looks at the}$ $\textbf{k nearest neighbors}$$\text{ and assigns the class appearing most frequently among those \\ neighbors.}$
#      - **$\textbf{Majority Voting}$**$\text{: The predicted class is the most common class among the nearest neighbors.
#      - $\text{}$Example: If `k=3` and the nearest neighbors are of classes [A, A, B], the predicted class is A.}$
#
#    - **$\text{KNN Regression}$**:
#      - $\text{For a given input, the KNN regressor looks at the **k nearest neighbors** and takes the **average** (or weighted average) of their target values to make a prediction.}$
#      - **$\textbf{Averaging}$**$\text{: The predicted value is the mean of the target values of the nearest neighbors.}$
#      - $\text{Example: If `k=3` and the target values of the nearest neighbors are [5, 7, 6], the predicted value would be `(5 + 7 + 6) / 3 = 6`.}$
#
# ---
#
# ##### $\textbf{3. Output:}$
#    - **$\text{KNN Classifier}$**:
#      - $\text{The output is a }$$\textbf{discrete class label}$$\text{ (categorical value).}$
#      - $\text{Example: "Spam" or "Not Spam."}$
#
#    - **$\text{KNN Regression}$**:
#      - $\text{The output is a }$$\textbf{continuous numerical value}$.
#      - $\text{Example: Predicted house price of 250,000.}$
#
# ---
#
# ##### **$\textbf{4. Distance Metric:}$**
#    - $\text{Both methods rely on the concept of }$$\textbf{distance}$$\text{ between data points (often Euclidean distance) to find the nearest neighbors. However, the distance metric itself is the same for both classifiers and regressors, but the way the distance is used to generate the output differs.}$
#
# ---
#
# ##### **$\textbf{5. Use Cases:}$**
#    - **$\text{KNN Classifier}$**:
#      - $\text{Typically used in scenarios where the data can be categorized into different classes.}$
#      - $\text{Example: Image classification, medical diagnosis (disease classification), text classification.}$
#
#    - **$\text{KNN Regression}$**:
#      - $\text{Used when the goal is to predict continuous quantities based on the features.}$
#      - $\text{Example: Predicting temperature, sales forecasting, stock market predictions.}$
#
# ---
#
# ##### $\textbf{Summary:}$
#
# - $\text{\textbf{KNN Classifier} is used for predicting categorical labels (class labels), with the prediction based on the most common label among the neighbors.}$
# - $\text{\textbf{KNN Regression} is used for predicting continuous values, with the prediction based on the average value of the neighbors.}$
#
# $\text{Both methods share the core principle of "nearness" and rely on a chosen distance metric to find the most similar instances. The distinction lies in how the \hfill predictions are made: \textbf{class labels} for classification and \textbf{continuous values} for regression.}$

# %% [markdown]
# ### Q3

# %% [markdown]
# #### 3. Suppose we have a data set with five predictors, \( $X_1$ = $\text{GPA}$, $X_2$ = $\text{IQ}$, $X_3$ = $\text{Level}$ \) (1 for College and 0 for High School), \( $X_4$ = \) Interaction between GPA and IQ, and \( $X_5$ = \) Interaction between GPA and Level. The response is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get:
# $$
# \hat{\beta}_0 = 50, \hat{\beta}_1 = 20, \hat{\beta}_2 = 0.07, \hat{\beta}_3 = 35, \hat{\beta}_4 = 0.01, \hat{\beta}_5 = -10.
# $$

# %% [markdown]
# #### (a) Which answer is correct, and why?
#
# **i.** For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates.
#
# **ii.** For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates.
#
# **iii.** For a fixed value of IQ and GPA, high school graduates earn more, on average, than college graduates provided that the GPA is high enough.
#
# **iv.** For a fixed value of IQ and GPA, college graduates earn more, on average, than high school graduates provided that the GPA is high enough.
#
# ##### <span style="color: rgb(190, 135, 215);">Answer</span>
# ##### According to the parameters given, the equation for a fixed value of IQ and GPA will be
#
# $$Y_{college}-Y_{high school} = 35 - 10*GPA$$
# ##### GPA will be in between 0.0 - 4.0 so that the interval of the equation above will be [-5,35] Which means that if GPA value is high enough, high school graduates can earn more than college graduates. Therefore answer is **iii**
# ---
#
# #### (b) Predict the salary of a college graduate with IQ of 110 and a GPA of 4.0.
#
# **Prediction Formula:**
# For a college graduate, \( $X_3$ = 1 \), so the prediction is based on the equation:
# $$
# \hat{Y} = 50 + 20 \times 4.0 + 0.07 \times 110 + 35 \times 1 + 0.01 \times (110 \times 4.0) - 10 \times (4.0 \times 1) = 137.1
# $$
#
# ---
#
# #### (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.
#
# **Answer:**
# - **False.**
# - **Justification:**
#   Even though the coefficient for the GPA/IQ interaction term is small, its presence indicates that the relationship between GPA and starting salary differs for college and high school graduates. The small value suggests that the interaction effect may not be the dominant factor (or If parameters are not normalized, GPA*IQ will be a big number), but it is still an important part of the model and should not be dismissed.

# %% [markdown]
# ### Q4

# %% [markdown]
# #### (a) Suppose that the true relationship between \( X \) and $ Y $ is linear, i.e. $ Y = \beta_0 + \beta_1 X + \epsilon $. Consider the training residual sum of squares (RSS) for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
#
# **Answer:**
# - **Expectation:** We would expect the cubic regression to have a lower training RSS than the linear regression.
# - **Reasoning:** The cubic regression has more flexibility, which allows it to fit the data more closely, potentially reducing the training error. However, this may lead to overfitting.
#
# ---
#
# #### (b) Answer (a) using test rather than training RSS.
#
#
# **Answer:**
# - **Expectation:** We would expect the linear regression to perform better in terms of test RSS.
# - **Reasoning:** The linear regression is less likely to overfit the data compared to the cubic regression, which may overfit and perform poorly on the test set.
#
# ---
#
# #### (c) Suppose that the true relationship between $ X $ and $ Y $ is not linear, but we don’t know how far it is from linear. Consider the training RSS for the linear regression, and also the training RSS for the cubic regression. Would we expect one to be lower than the other, would we expect them to be the same, or is there not enough information to tell? Justify your answer.
#
#
# **Answer:**
# - **Expectation:** We would expect the cubic regression to have a lower training RSS.
# - **Reasoning:** Even if the true relationship is not linear, the cubic regression has more flexibility to approximate the true relationship, thus lowering the training RSS.
#
# ---
#
# #### (d) Answer (c) using test rather than training RSS.
#
#
# **Answer:**
# - **Expectation:** Not enough information to tell.
# - **Reasoning:** While the cubic regression may fit the test data better if the data is non-linear, linear regression may fit the test data better if the data is linear. Therefore, the answer will change according to the fact how far the data is from linearity.

# %% [markdown]
# ### Q5

# %% [markdown]
# #### 5. Consider the fitted values that result from performing linear regression without an intercept. In this setting, the \(i\)-th fitted value takes the form
# $$
# \[
# \hat{y}_i = x_i \hat{\beta},
# \]
# $$
# where
# $$
# \[
# \hat{\beta} = \frac{\sum_{i=1}^{n} x_i y_i}{\sum_{i'=1}^{n} x_i^2}.
# \]
# $$
# Show that we can write
# $$
# \[
# \hat{y}_i = \sum_{i'=1}^{n} a_{i'} y_{i'}.
# \]
# $$
#
# What is $\(a_{i'}\)?$
# **Note:** We interpret this result by saying that the fitted values from linear regression are linear combinations of the response values.
#
#
# To be more clear, instead of using i', I will use i,j,k,t etc.
# $$
# \[
# \hat{y}_i = x_i \hat{\beta}=x_i \times \frac{\sum_{t=1}^{n} x_t y_t}{\sum_{j=1}^{n} x_j^2} = \sum_{k=1}^{n} a_{k} y_{k} ,
# \]
# $$
# The fraction will be
# $$
# \[
# \hat{y}_i = \frac{(x_i \times x_1 \times y_1) \plus (x_i \times x_2 \times y_2) \plus \cdots (x_i \times x_n \times y_n)}{(x_1 \times x_1) \plus (x_1 \times x_1) \plus \cdots (x_n \times x_n)} ,
# \]
# $$
#
# By the definition, we know that
# $$
# \[
# \frac{a \plus b}{c} = \frac{a}{c} \plus \frac{b}{c} ,
# \]
# $$
# Therefore we can write the fraction like
# $$
# \[
# \hat{y}_i = \sum_{t=1}^{n} \frac{ x_i \times x_t \times y_t}{\sum_{j=1}^{n} x_j^2} = \sum_{t=1}^{n} \frac{ x_i \times  x_t}{\sum_{j=1}^{n} x_j^2} \times y_t = \sum_{k=1}^{n} a_{k} y_{k} ,
# \]
# $$
#
# Now, we can clearly see that both side of the equation looks similar. k and t letters are just referring the same range. Therefore, we can write $a_k$ as
#
# $$
# \[
# a_k = \frac{x_i \times x_k}{\sum_{j=1}^{n} x_j^2}
# \]
# $$

# %% [markdown]
# ### Q6

# %% [markdown]
# #### 6. Using (3.4), argue that in the case of simple linear regression, the least squares line always passes through the point $\( (\bar{x}, \bar{y}) \)$.
#
# ![Data Set](e6.png)
#
#
# We know that linear regression formula is
# $$
# \[
# \hat{y} = \hat{\beta_0} \plus \hat{\beta_1} \times x
# \]
# $$
#
# where $\hat{\beta_0}$ and $\hat{\beta_1}$ are the estimation of the coefficients by least square. By definition in (3.4),  $\hat{\beta_0}$ can be written as
#
# $$
# \[
# \hat{\beta_0} = \bar{y} \minus \hat{\beta_1} \times \bar{x}
# \]
# $$
#
# where \bar{y} and \bar{x} refers the mean of the x and y values in dataset. If we put $\hat{\beta_0}$ in the equation, we get
#
# $$
# \[
# \hat{y} = \bar{y} \minus \hat{\beta_1} \times \bar{x} \plus \hat{\beta_1} \times x
# \]
# $$
#
# If the case is true, when $x$ is $\bar{x}$ the prediction ($\hat{y}$) should be $\bar{y}$
#
# $$
# \[
# \hat{y} = \bar{y} \minus \hat{\beta_1} \times \bar{x} \plus \hat{\beta_1} \times \bar{x}
# \]
# $$
#
# $$
# \[
# \hat{y} = \bar{y}
# \]
# $$
#
# We proved that in whatever dataset, the least squares line always passes through the point ($\bar{x}$,$\bar{y}$)

# %% [markdown]
# ### Q7

# %% [markdown]
# #### 7. It is claimed in the text that in the case of simple linear regression of $\( Y \)$ onto $\( X \)$, the $\( R^2 \)$ statistic (3.17) is equal to the square of the correlation between $\( X \)$ and $\( Y \)$ (3.18). Prove that this is the case. For simplicity, you may assume that $\( \bar{x} = \bar{y} = 0 \)$.
#
# ![Dataset](e7-1.png)
#
# ![Dataset](e7-2.png)
#
# To be clear, let's write the definitions that we know and we will use.
#
# Question says
# $$
# \[
# \bar{y} = 0
# \]
# $$
#
# $$
# \[
# \bar{x} = 0
# \]
# $$
#
# Therefore, redefinition of the formulas as
#
# $$
# \[
# R^2 = \frac{TSS \minus RSS}{TSS} = 1 \minus \frac{RSS}{TSS}
# \]
# $$
#
# $$
# \[
# TSS = \sum_{i=1}^{n} (y_i \minus \bar{y})^2 = \sum_{i=1}^{n} (y_i)^2
# \]
# $$
#
# $$
# \[
# RSS = \sum_{i=1}^{n} (y_i \minus \hat{y})^2
# \]
# $$
#
#
#
# By definition in least squares,
#
# $$
# \[
# \hat{y} = \beta_0 \plus \beta_1 \times x
# \]
# $$
#
# $$
# \[
# \beta_0 = \bar{y} \minus \beta_1 \times x = 0
# \]
# $$
#
# $$
# \[
# \beta_1 = \frac{\sum_{i=1}^{n}((x_i \minus \bar{x}) \times (y_i \minus \bar{y}))}{\sum_{i=1}^{n}(x_i \minus \bar{x})^2} = \frac{\sum_{i=1}^{n}(x_i \times y_i)}{\sum_{i=1}^{n}x_i^2}
# \]
# $$
#
# Definiton of the square of the correlation between $X$ and $Y$
#
# $$
# \[
# Cor(X,Y) = \frac{\sum_{i=1}^{n}((x_i \minus \bar{x}) \times (y_i \minus \bar{y}))}{\sqrt{\sum_{i=1}^{n}(x_i \minus \bar{x})^2} \times \sqrt{\sum_{i=1}^{n}(y_i \minus \bar{y})^2}}
# \]
# $$
#
#
# Now, we can re-write $R^2$ by using the formulas above as
#
# $$
# \[
# R^2 = 1 \minus \frac{\sum_{i=1}^{n} (y_i \minus \hat{y})^2}{\sum_{i=1}^{n} (y_i)^2} = 1 \minus \frac{\sum_{i=1}^{n} (y_i \minus \beta_1 \times x_i)^2}{\sum_{i=1}^{n} (y_i)^2}
# \]
# $$
#
# After expanding the numerator
#
# $$
# \[
# R^2 = 1 \minus \frac{\sum_{i=1}^{n} (y_i^2 + \minus 2 \times \beta_1 \times x_i \times y_i \plus \beta_1^2 \times x_i^2)}{\sum_{i=1}^{n} (y_i)^2} = 1 \minus 1 \plus \frac{2 \times \beta_1 \times \sum_{i=1}^{n}(x_i \times y_i) \minus \beta_1^2 \times \sum_{i=1}^{n}(x_i)^2}{\sum_{i=1}^{n} (y_i)^2}
# \]
# $$
#
# and putting $\beta_1$ value
#
#
# $$
# \[
# R^2 = \frac{2 \times \frac{\sum_{i=1}^{n}(x_i \times y_i)}{\sum_{i=1}^{n}x_i^2} \times \sum_{i=1}^{n}(x_i \times y_i) \minus (\frac{\sum_{i=1}^{n}(x_i \times y_i)}{\sum_{i=1}^{n}x_i^2})^2 \times \sum_{i=1}^{n}(x_i)^2}{\sum_{i=1}^{n} (y_i)^2}
# \]
# $$
#
# Which simplified as
#
# $$
# \[
# R^2 = \frac{(\sum_{i=1}^{n}(x_i \times y_i))^2}{\sum_{i=1}^{n} (x_i)^2 \times \sum_{i=1}^{n} (y_i)^2}
# \]
# $$
#
# Now, If we look at the square of correlation
#
# $$
# \[
# Cor^2(X,Y) = \frac{(\sum_{i=1}^{n}((x_i \minus \bar{x}) \times (y_i \minus \bar{y})))^2}{(\sqrt{\sum_{i=1}^{n}(x_i \minus \bar{x})^2})^2 \times (\sqrt{\sum_{i=1}^{n}(y_i \minus \bar{y})^2})^2} = \frac{(\sum_{i=1}^{n}(x_i \times y_i))^2}{\sum_{i=1}^{n} (x_i)^2 \times \sum_{i=1}^{n} (y_i)^2} = R^2
# \]
# $$
#
# Thus, we proved that $R^2$ is equal to the square of the correlation between $X$ and $Y$ in the case of simple linear regression.

# %% [markdown]
# ## <span style="color: rgb(0, 105, 175);">*Applied*</span>

# %% [markdown]
# ### Q8

# %% [markdown]
# #### 8. This question involves the use of simple linear regression on the <span style="color: rgb(145, 75, 40);">Auto</span> data set
#
# #### (a) Use the <span style="color: rgb(145, 75, 40);">sm.OLS()</span> function to perform a simple linear regression with <span style="color: rgb(145, 75, 40);">mpg</span> as the response and <span style="color: rgb(145, 75, 40);">horsepower</span> as the predictor. Use the <span style="color: rgb(145, 75, 40);">summarize()</span> function to print the results. Comment on the output. For example:
#
# **i.** Is there a relationship between the predictor and the response?
#
# **ii.** How strong is the relationship between the predictor and the response?
#
# **iii.** Is the relationship between the predictor and the response positive or negative?
#
# **iv.** What is the predicted mpg associated with a horsepower of 98? What are the associated 95 % confidence and prediction intervals?

# %% [markdown]
# ##### To answer these questions, we need to train the model first.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf  # Statsmodels is a Python module for statistics
import statsmodels.api as sm
from ISLP import load_data
import scipy.stats as stats

# %%
Auto = load_data("Auto") #Loading data

# %%
Auto.head()
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0         130    3504
# buick skylark 320          15.0          8         350.0         165    3693
# plymouth satellite         18.0          8         318.0         150    3436
# amc rebel sst              16.0          8         304.0         150    3433
# ford torino                17.0          8         302.0         140    3449
#
#                            acceleration  year  origin
# name
# chevrolet chevelle malibu          12.0    70       1
# buick skylark 320                  11.5    70       1
# plymouth satellite                 11.0    70       1
# amc rebel sst                      12.0    70       1
# ford torino                        10.5    70       1

# %% [markdown]
# ##### Some of observations about data

# %%
Auto["horsepower"].isnull().sum() #Checking number of null variables in predictor
# Out:
# 0

# %%
Auto["mpg"].isnull().sum() #Checking number of null variables in response
# Out:
# 0

# %%
Auto["horsepower"].unique() #Checking if there is abnormal value (like negative value, text value etc.)
# Out:
# array([130, 165, 150, 140, 198, 220, 215, 225, 190, 170, 160,  95,  97,
#         85,  88,  46,  87,  90, 113, 200, 210, 193, 100, 105, 175, 153,
#        180, 110,  72,  86,  70,  76,  65,  69,  60,  80,  54, 208, 155,
#        112,  92, 145, 137, 158, 167,  94, 107, 230,  49,  75,  91, 122,
#         67,  83,  78,  52,  61,  93, 148, 129,  96,  71,  98, 115,  53,
#         81,  79, 120, 152, 102, 108,  68,  58, 149,  89,  63,  48,  66,
#        139, 103, 125, 133, 138, 135, 142,  77,  62, 132,  84,  64,  74,
#        116,  82])

# %%
Auto[["horsepower","mpg"]].corr()
# Out:
#             horsepower       mpg
# horsepower    1.000000 -0.778427
# mpg          -0.778427  1.000000

# %%
pd.plotting.scatter_matrix(Auto[["horsepower","mpg"]])
# Out:
# array([[<Axes: xlabel='horsepower', ylabel='horsepower'>,
#         <Axes: xlabel='mpg', ylabel='horsepower'>],
#        [<Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='mpg', ylabel='mpg'>]], dtype=object)

# %% [markdown]
# ##### Generally speaking, there is a negative correlation between mpg and horsepower. (E.g. A ferrari can go 200km with a full of gas tank while a family car can go 500km etc.) Let's now train the model

# %%
mod = smf.ols(formula='mpg ~ horsepower', data = Auto)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.605
# Method:                 Least Squares   F-statistic:                     599.7
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           7.03e-81
# Time:                        12:31:08   Log-Likelihood:                -1178.7
# No. Observations:                 392   AIC:                             2361.
# Df Residuals:                     390   BIC:                             2369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.9359      0.717     55.660      0.000      38.525      41.347
# ...

# %% [markdown]
# #### Here is the explanation of all information in the summary
#
# #### OLS Regression Results Explanation
#
# The output provided is the result of an Ordinary Least Squares (OLS) regression analysis. Below is a detailed explanation of each part of the result:
#
# ##### 1. **Dep. Variable**: `mpg`
#    - **Meaning**: This is the dependent variable (or outcome variable) in the regression model. In this case, it's the variable `mpg`, which represents "miles per gallon" of a car.
#
# ##### 2. **R-squared**: `0.606`
#    - **Meaning**: This statistic represents the proportion of the variance in the dependent variable (`mpg`) that is explained by the independent variable(s) in the model. An R-squared of 0.606 means that about 60.6% of the variability in `mpg` can be explained by the horsepower of the car in this model.
#
# ##### 3. **Adj. R-squared**: `0.605`
#    - **Meaning**: The adjusted R-squared accounts for the number of predictors in the model and adjusts for the potential overfitting of the model. This value is very close to R-squared, suggesting that adding more predictors (or independent variables) would not substantially improve the model.
#
# ##### 4. **Method**: `Least Squares`
#    - **Meaning**: This indicates that the Ordinary Least Squares method was used to estimate the coefficients in the regression model. OLS minimizes the sum of squared residuals to find the best-fitting line.
#
# ##### 5. **F-statistic**: `599.7`
#    - **Meaning**: The F-statistic tests whether at least one of the predictors in the model has a non-zero coefficient. A high F-statistic value suggests that the model is a good fit for the data.
#
# ##### 6. **Prob (F-statistic)**: `7.03e-81`
#    - **Meaning**: This is the p-value for the F-statistic, which is extremely small (close to zero). This suggests that the overall model is statistically significant, and at least one predictor has a significant relationship with the dependent variable.
#
# ##### 7. **Date & Time**
#    - **Meaning**: The date and time when the analysis was conducted.
#
# ##### 8. **No. Observations**: `392`
#    - **Meaning**: The number of observations (data points) used in the regression analysis. There are 392 records used to estimate the model.
#
# ##### 9. **Df Residuals**: `390`
#    - **Meaning**: The degrees of freedom for the residuals (the difference between the number of observations and the number of estimated parameters). It is equal to `392 - 2 = 390`, since two parameters (intercept and coefficient of horsepower) are estimated.
#
# ##### 10. **Df Model**: `1`
#    - **Meaning**: The number of independent variables (predictors) in the model. Here, there is only one predictor, `horsepower`.
#
# ##### 11. **Covariance Type**: `nonrobust`
#    - **Meaning**: The standard errors provided assume the covariance matrix of the errors is correctly specified. A "nonrobust" covariance type means that no adjustments were made for heteroscedasticity or other potential violations of the model assumptions.
#
# ##### Coefficients Table
# | Variable      | Coefficient | Std. Error | t-Statistic | P-value  | 95% Confidence Interval |
# |---------------|-------------|------------|-------------|----------|-------------------------|
# | **Intercept** | 39.9359     | 0.717      | 55.660      | 0.000    | [38.525, 41.347]        |
# | **Horsepower**| -0.1578     | 0.006      | -24.489     | 0.000    | [-0.171, -0.145]        |
#
# ###### Intercept:
#    - **Coefficient**: `39.9359`
#      - This is the estimated value of `mpg` when the horsepower is zero. It represents the baseline `mpg` when there is no horsepower in the model.
#    - **Std. Error**: `0.717`
#      - The standard error of the intercept, which reflects the uncertainty in the estimate of the intercept.
#    - **t-statistic**: `55.660`
#      - The t-statistic tests whether the intercept is significantly different from zero. A large absolute t-value suggests that the intercept is highly significant.
#    - **P-value**: `0.000`
#      - A very small p-value (less than 0.05) indicates that the intercept is statistically significant and different from zero.
#    - **95% Confidence Interval**: [38.525, 41.347]
#      - This is the range of values within which the true intercept is likely to fall with 95% confidence.
#
# ###### Horsepower:
#    - **Coefficient**: `-0.1578`
#      - This is the estimated change in `mpg` for each one-unit increase in horsepower. The negative sign indicates that as horsepower increases, `mpg` decreases.
#    - **Std. Error**: `0.006`
#      - The standard error of the coefficient for horsepower.
#    - **t-statistic**: `-24.489`
#      - The t-statistic tests whether the coefficient for horsepower is significantly different from zero. The large negative value indicates that it is significant.
#    - **P-value**: `0.000`
#      - The very small p-value shows that the relationship between horsepower and `mpg` is statistically significant.
#    - **95% Confidence Interval**: [-0.171, -0.145]
#      - This range suggests that for each additional horsepower, `mpg` will decrease between 0.145 and 0.171 units, with 95% confidence.
#
# ##### 12. **Omnibus**: `16.432`
#    - **Meaning**: The Omnibus test is used to check if the residuals (errors) are normally distributed. A significant value indicates that the residuals may not follow a normal distribution.
#
# ##### 13. **Durbin-Watson**: `0.920`
#    - **Meaning**: The Durbin-Watson statistic tests for autocorrelation in the residuals. A value near 2 indicates no autocorrelation. A value of 0.920 suggests some positive autocorrelation may exist in the residuals.
#
# ##### 14. **Jarque-Bera (JB)**: `17.305`
#    - **Meaning**: The Jarque-Bera test also assesses the normality of residuals, based on skewness and kurtosis. A large JB statistic (and its associated p-value) indicates that the residuals deviate from normality.
#
# ##### 15. **Skew**: `0.492`
#    - **Meaning**: The skewness value measures the asymmetry of the distribution of residuals. A value close to zero suggests that the residuals are fairly symmetric.
#
# ##### 16. **Kurtosis**: `3.299`
#    - **Meaning**: Kurtosis indicates the "tailedness" of the residuals. A kurtosis value of 3 suggests that the residuals have a normal distribution (as a normal distribution has a kurtosis of 3).
#
# ##### 17. **Condition Number**: `322`
#    - **Meaning**: This value indicates potential multicollinearity in the model. A high condition number may suggest issues with multicollinearity, though values above 30 are typically considered problematic.
#
# ##### Summary:
# The OLS regression suggests that horsepower has a significant negative relationship with `mpg`, meaning that as horsepower increases, fuel efficiency (miles per gallon) tends to decrease. The model is statistically significant and explains about 60.6% of the variance in `mpg`.

# %% [markdown]
# #### Now for the question 8.a
#
# ##### i. Is there a relationship between the predictor and the response?
# Yes, there is a relationship between the predictor (horsepower) and the response (mpg), as indicated by the significant p-value for the horsepower coefficient (p < 0.0001).
#
# ##### ii. How strong is the relationship between the predictor and the response?
# The relationship is moderately strong, with an R-squared of 0.606. This means that 60.6% of the variation in mpg is explained by horsepower.
#
# ##### iii. Is the relationship between the predictor and the response positive or negative?
# The relationship is negative. The coefficient for horsepower is -0.1578, indicating that as horsepower increases, mpg decreases.
#
# ##### iv. What is the predicted mpg associated with a horsepower of 98? What are the associated 95% confidence and prediction intervals?
# To calculate the predicted mpg for a horsepower of 98:
# - Predicted mpg = Intercept + (Horsepower coefficient * Horsepower value)
# - Predicted mpg = 39.9359 + (-0.1578 * 98)

# %% [markdown]
# #### (b) Plot the response and the predictor in a new set of axes <span style="color: rgb(145, 75, 40);">ax</span>. Use the <span style="color: rgb(145, 75, 40);">ax.axline()</span> method or the <span style="color: rgb(145, 75, 40);">abline()</span> function defined in the lab to display the least squares regression line.

# %%
res.params
# Out:
# Intercept     39.935861
# horsepower    -0.157845
# dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming you have your OLS results (res) and 'Auto' dataset available

# Get actual horsepower and mpg values
horsepower_values = Auto["horsepower"].astype("float")
mpg_values = Auto["mpg"]  # Actual mpg values

# Calculate the predicted mpg values using the regression model
predicted_mpg = res.params[0] + res.params[1] * horsepower_values

# Plotting the data and the regression line
fig, ax = plt.subplots(figsize=(8, 6))

# Scatter plot for the actual data points (real horsepower and mpg)
ax.scatter(horsepower_values, mpg_values, label="Data points", color='blue')

# Least squares regression line using ax.plot() for the predicted mpg values
# We plot the predicted values using a smooth line across the range of horsepower values
sorted_horsepower = sorted(horsepower_values)
predicted_line = res.params[0] + res.params[1] * pd.Series(sorted_horsepower)

# Plotting the regression line (prediction line)
ax.plot(sorted_horsepower, predicted_line, color='red', label="Regression Line")

# Adding labels and title
ax.set_xlabel('Horsepower')
ax.set_ylabel('MPG')
ax.set_title('Regression Line of MPG vs Horsepower')

# Show legend
ax.legend()

# Display the plot
plt.show()
# Out:
# /var/folders/6r/cs7m9yw905q4n_v543s39ddh0000gn/T/ipykernel_956/3252217652.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   predicted_mpg = res.params[0] + res.params[1] * horsepower_values
# /var/folders/6r/cs7m9yw905q4n_v543s39ddh0000gn/T/ipykernel_956/3252217652.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   predicted_line = res.params[0] + res.params[1] * pd.Series(sorted_horsepower)

# %% [markdown]
# #### (c) Produce some of diagnostic plots of the least squares regression fit as described in the lab. Comment on any problems you see with the fit.

# %%
# Get the residuals and fitted values
residuals = res.resid
fitted_values = res.fittedvalues

plt.clf()
# 1. Residuals vs Fitted Values Plot
fig, ax = plt.subplots(figsize=(8, 6))
ax = sns.residplot(data=Auto, x=res.fittedvalues, y="mpg", lowess=True, line_kws=dict(color="r"))
ax.set_xlabel('Fitted Values')
ax.set_ylabel('Residuals')
ax.set_title('Residuals vs Fitted Values')
abs_resid = res.resid.sort_values(ascending=False)
abs_resid_top_3 = abs_resid[:3]

for i in abs_resid_top_3.index:
    ax.annotate(i, xy=(res.fittedvalues[i], res.resid[i]));
plt.show()

# %%
# base code
import numpy as np
import seaborn as sns
from statsmodels.tools.tools import maybe_unwrap_results
from statsmodels.graphics.gofplots import ProbPlot
from statsmodels.stats.outliers_influence import variance_inflation_factor
import matplotlib.pyplot as plt
from typing import Type

style_talk = 'seaborn-talk'    #refer to plt.style.available

class LinearRegDiagnostic():
    """
    Diagnostic plots to identify potential problems in a linear regression fit.
    Mainly,
        a. non-linearity of data
        b. Correlation of error terms
        c. non-constant variance
        d. outliers
        e. high-leverage points
        f. collinearity

    Authors:
        Prajwal Kafle (p33ajkafle@gmail.com, where 3 = r)
        Does not come with any sort of warranty.
        Please test the code one your end before using.

        Matt Spinelli (m3spinelli@gmail.com, where 3 = r)
        (1) Fixed incorrect annotation of the top most extreme residuals in
            the Residuals vs Fitted and, especially, the Normal Q-Q plots.
        (2) Changed Residuals vs Leverage plot to match closer the y-axis
            range shown in the equivalent plot in the R package ggfortify.
        (3) Added horizontal line at y=0 in Residuals vs Leverage plot to
            match the plots in R package ggfortify and base R.
        (4) Added option for placing a vertical guideline on the Residuals
            vs Leverage plot using the rule of thumb of h = 2p/n to denote
            high leverage (high_leverage_threshold=True).
        (5) Added two more ways to compute the Cook's Distance (D) threshold:
            * 'baseR': D > 1 and D > 0.5 (default)
            * 'convention': D > 4/n
            * 'dof': D > 4 / (n - k - 1)
        (6) Fixed class name to conform to Pascal casing convention
        (7) Fixed Residuals vs Leverage legend to work with loc='best'
    """

    def __init__(self,
                 results: Type[sm.regression.linear_model.RegressionResultsWrapper]) -> None:
        """
        For a linear regression model, generates following diagnostic plots:

        a. residual
        b. qq
        c. scale location and
        d. leverage

        and a table

        e. vif

        Args:
            results (Type[statsmodels.regression.linear_model.RegressionResultsWrapper]):
                must be instance of statsmodels.regression.linear_model object

        Raises:
            TypeError: if instance does not belong to above object

        Example:
        >>> import numpy as np
        >>> import pandas as pd
        >>> import statsmodels.formula.api as smf
        >>> x = np.linspace(-np.pi, np.pi, 100)
        >>> y = 3*x + 8 + np.random.normal(0,1, 100)
        >>> df = pd.DataFrame({'x':x, 'y':y})
        >>> res = smf.ols(formula= "y ~ x", data=df).fit()
        >>> cls = Linear_Reg_Diagnostic(res)
        >>> cls(plot_context="seaborn-v0_8-paper")

        In case you do not need all plots you can also independently make an individual plot/table
        in following ways

        >>> cls = Linear_Reg_Diagnostic(res)
        >>> cls.residual_plot()
        >>> cls.qq_plot()
        >>> cls.scale_location_plot()
        >>> cls.leverage_plot()
        >>> cls.vif_table()
        """

        if isinstance(results, sm.regression.linear_model.RegressionResultsWrapper) is False:
            raise TypeError("result must be instance of statsmodels.regression.linear_model.RegressionResultsWrapper object")

        self.results = maybe_unwrap_results(results)

        self.y_true = self.results.model.endog
        self.y_predict = self.results.fittedvalues
        self.xvar = self.results.model.exog
        self.xvar_names = self.results.model.exog_names

        self.residual = np.array(self.results.resid)
        influence = self.results.get_influence()
        self.residual_norm = influence.resid_studentized_internal
        self.leverage = influence.hat_matrix_diag
        self.cooks_distance = influence.cooks_distance[0]
        self.nparams = len(self.results.params)
        self.nresids = len(self.residual_norm)

    def __call__(self, plot_context='seaborn-v0_8-paper', **kwargs):
        # print(plt.style.available)
        # GH#9157
        if plot_context not in plt.style.available:
            plot_context = 'default'
        with plt.style.context(plot_context):
            fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10))
            self.residual_plot(ax=ax[0,0])
            self.qq_plot(ax=ax[0,1])
            self.scale_location_plot(ax=ax[1,0])
            self.leverage_plot(
                ax=ax[1,1],
                high_leverage_threshold = kwargs.get('high_leverage_threshold'),
                cooks_threshold = kwargs.get('cooks_threshold'))
            plt.show()

        return self.vif_table(), fig, ax,

    def residual_plot(self, ax=None):
        """
        Residual vs Fitted Plot

        Graphical tool to identify non-linearity.
        (Roughly) Horizontal red line is an indicator that the residual has a linear pattern
        """
        if ax is None:
            fig, ax = plt.subplots()

        sns.residplot(
            x=self.y_predict,
            y=self.residual,
            lowess=True,
            scatter_kws={'alpha': 0.5},
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        residual_abs = np.abs(self.residual)
        abs_resid = np.flip(np.argsort(residual_abs), 0)
        abs_resid_top_3 = abs_resid[:3]
        for i in abs_resid_top_3:
            ax.annotate(
                i,
                xy=(self.y_predict[i], self.residual[i]),
                color='C3')

        ax.set_title('Residuals vs Fitted', fontweight="bold")
        ax.set_xlabel('Fitted values')
        ax.set_ylabel('Residuals')
        return ax

    def qq_plot(self, ax=None):
        """
        Standarized Residual vs Theoretical Quantile plot

        Used to visually check if residuals are normally distributed.
        Points spread along the diagonal line will suggest so.
        """
        if ax is None:
            fig, ax = plt.subplots()

        QQ = ProbPlot(self.residual_norm)
        fig = QQ.qqplot(line='45', alpha=0.5, lw=1, ax=ax)

        # annotations
        abs_norm_resid = np.flip(np.argsort(np.abs(self.residual_norm)), 0)
        abs_norm_resid_top_3 = abs_norm_resid[:3]
        for i, x, y in self.__qq_top_resid(QQ.theoretical_quantiles, abs_norm_resid_top_3):
            ax.annotate(
                i,
                xy=(x, y),
                ha='right',
                color='C3')

        ax.set_title('Normal Q-Q', fontweight="bold")
        ax.set_xlabel('Theoretical Quantiles')
        ax.set_ylabel('Standardized Residuals')
        return ax

    def scale_location_plot(self, ax=None):
        """
        Sqrt(Standarized Residual) vs Fitted values plot

        Used to check homoscedasticity of the residuals.
        Horizontal line will suggest so.
        """
        if ax is None:
            fig, ax = plt.subplots()

        residual_norm_abs_sqrt = np.sqrt(np.abs(self.residual_norm))

        ax.scatter(self.y_predict, residual_norm_abs_sqrt, alpha=0.5);
        sns.regplot(
            x=self.y_predict,
            y=residual_norm_abs_sqrt,
            scatter=False, ci=False,
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        abs_sq_norm_resid = np.flip(np.argsort(residual_norm_abs_sqrt), 0)
        abs_sq_norm_resid_top_3 = abs_sq_norm_resid[:3]
        for i in abs_sq_norm_resid_top_3:
            ax.annotate(
                i,
                xy=(self.y_predict[i], residual_norm_abs_sqrt[i]),
                color='C3')

        ax.set_title('Scale-Location', fontweight="bold")
        ax.set_xlabel('Fitted values')
        ax.set_ylabel(r'$\sqrt{|\mathrm{Standardized\ Residuals}|}$');
        return ax

    def leverage_plot(self, ax=None, high_leverage_threshold=False, cooks_threshold='baseR'):
        """
        Residual vs Leverage plot

        Points falling outside Cook's distance curves are considered observation that can sway the fit
        aka are influential.
        Good to have none outside the curves.
        """
        if ax is None:
            fig, ax = plt.subplots()

        ax.scatter(
            self.leverage,
            self.residual_norm,
            alpha=0.5);

        sns.regplot(
            x=self.leverage,
            y=self.residual_norm,
            scatter=False,
            ci=False,
            lowess=True,
            line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8},
            ax=ax)

        # annotations
        leverage_top_3 = np.flip(np.argsort(self.cooks_distance), 0)[:3]
        for i in leverage_top_3:
            ax.annotate(
                i,
                xy=(self.leverage[i], self.residual_norm[i]),
                color = 'C3')

        factors = []
        if cooks_threshold == 'baseR' or cooks_threshold is None:
            factors = [1, 0.5]
        elif cooks_threshold == 'convention':
            factors = [4/self.nresids]
        elif cooks_threshold == 'dof':
            factors = [4/ (self.nresids - self.nparams)]
        else:
            raise ValueError("threshold_method must be one of the following: 'convention', 'dof', or 'baseR' (default)")
        for i, factor in enumerate(factors):
            label = "Cook's distance" if i == 0 else None
            xtemp, ytemp = self.__cooks_dist_line(factor)
            ax.plot(xtemp, ytemp, label=label, lw=1.25, ls='--', color='red')
            ax.plot(xtemp, np.negative(ytemp), lw=1.25, ls='--', color='red')

        if high_leverage_threshold:
            high_leverage = 2 * self.nparams / self.nresids
            if max(self.leverage) > high_leverage:
                ax.axvline(high_leverage, label='High leverage', ls='-.', color='purple', lw=1)

        ax.axhline(0, ls='dotted', color='black', lw=1.25)
        ax.set_xlim(0, max(self.leverage)+0.01)
        ax.set_ylim(min(self.residual_norm)-0.1, max(self.residual_norm)+0.1)
        ax.set_title('Residuals vs Leverage', fontweight="bold")
        ax.set_xlabel('Leverage')
        ax.set_ylabel('Standardized Residuals')
        plt.legend(loc='best')
        return ax

    def vif_table(self):
        """
        VIF table

        VIF, the variance inflation factor, is a measure of multicollinearity.
        VIF > 5 for a variable indicates that it is highly collinear with the
        other input variables.
        """
        vif_df = pd.DataFrame()
        vif_df["Features"] = self.xvar_names
        vif_df["VIF Factor"] = [variance_inflation_factor(self.xvar, i) for i in range(self.xvar.shape[1])]

        return (vif_df
                .sort_values("VIF Factor")
                .round(2))


    def __cooks_dist_line(self, factor):
        """
        Helper function for plotting Cook's distance curves
        """
        p = self.nparams
        formula = lambda x: np.sqrt((factor * p * (1 - x)) / x)
        x = np.linspace(0.001, max(self.leverage), 50)
        y = formula(x)
        return x, y


    def __qq_top_resid(self, quantiles, top_residual_indices):
        """
        Helper generator function yielding the index and coordinates
        """
        offset = 0
        quant_index = 0
        previous_is_negative = None
        for resid_index in top_residual_indices:
            y = self.residual_norm[resid_index]
            is_negative = y < 0
            if previous_is_negative == None or previous_is_negative == is_negative:
                offset += 1
            else:
                quant_index -= offset
            x = quantiles[quant_index] if is_negative else np.flip(quantiles, 0)[quant_index]
            quant_index += 1
            previous_is_negative = is_negative
            yield resid_index, x, y

# %%
cls = LinearRegDiagnostic(res)
cls.qq_plot();

# %%
cls.leverage_plot();
plt.ylim(-5,10)
# Out:
# (-5.0, 10.0)

# %%
cls.scale_location_plot();

# %%
cls.vif_table()
# Out:
#      Features  VIF Factor
# 1  horsepower        1.00
# 0   Intercept        8.39

# %% [markdown]
# ### Q9

# %% [markdown]
# #### $\text{9. This question involves the use of multiple linear regression on the \textcolor{145, 75, 40}{Auto} data set}$
#
# #### $\text{ (a) Produce a scatterplot matrix which includes all of the variables in the data set.}$

# %%
pd.plotting.scatter_matrix(Auto)
# Out:
# array([[<Axes: xlabel='mpg', ylabel='mpg'>,
#         <Axes: xlabel='cylinders', ylabel='mpg'>,
#         <Axes: xlabel='displacement', ylabel='mpg'>,
#         <Axes: xlabel='horsepower', ylabel='mpg'>,
#         <Axes: xlabel='weight', ylabel='mpg'>,
#         <Axes: xlabel='acceleration', ylabel='mpg'>,
#         <Axes: xlabel='year', ylabel='mpg'>,
#         <Axes: xlabel='origin', ylabel='mpg'>],
#        [<Axes: xlabel='mpg', ylabel='cylinders'>,
#         <Axes: xlabel='cylinders', ylabel='cylinders'>,
#         <Axes: xlabel='displacement', ylabel='cylinders'>,
#         <Axes: xlabel='horsepower', ylabel='cylinders'>,
#         <Axes: xlabel='weight', ylabel='cylinders'>,
#         <Axes: xlabel='acceleration', ylabel='cylinders'>,
#         <Axes: xlabel='year', ylabel='cylinders'>,
#         <Axes: xlabel='origin', ylabel='cylinders'>],
#        [<Axes: xlabel='mpg', ylabel='displacement'>,
#         <Axes: xlabel='cylinders', ylabel='displacement'>,
# ...

# %% [markdown]
# #### $\text{(b) Compute the matrix of correlations between the variables using the \textcolor{145, 75, 40}{DataFrame.corr()} method.}$

# %%
Auto.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.777618     -0.805127   -0.778427 -0.832244
# cylinders    -0.777618   1.000000      0.950823    0.842983  0.897527
# displacement -0.805127   0.950823      1.000000    0.897257  0.932994
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.832244   0.897527      0.932994    0.864538  1.000000
# acceleration  0.423329  -0.504683     -0.543800   -0.689196 -0.416839
# year          0.580541  -0.345647     -0.369855   -0.416361 -0.309120
# origin        0.565209  -0.568932     -0.614535   -0.455171 -0.585005
#
#               acceleration      year    origin
# mpg               0.423329  0.580541  0.565209
# cylinders        -0.504683 -0.345647 -0.568932
# displacement     -0.543800 -0.369855 -0.614535
# horsepower       -0.689196 -0.416361 -0.455171
# weight           -0.416839 -0.309120 -0.585005
# acceleration      1.000000  0.290316  0.212746
# ...

# %% [markdown]
# #### $\text{(c) Use the \textcolor{145, 75, 40}{sm.OLS()} function to perform a multiple linear regression with \textcolor{145, 75, 40}{mpg} as the response and all other variables except \\ \textcolor{145, 75, 40}{name} as the predictors. Use the \textcolor{145, 75, 40}{summarize()} function to print the results. Comment on the output. \\ For instance:}$
#
# **i** $\text{Is there a relationship between the predictors and the response? Use the \textcolor{145, 75, 40}{anova\_lm()} function from \textcolor{145, 75, 40}{statsmodels} to answer this question.}$

# %%
columns = [col for col in Auto.columns if col != "mpg"]
model_parameter = "mpg~"+"+".join(columns)
model_parameter
# Out:
# 'mpg~cylinders+displacement+horsepower+weight+acceleration+year+origin'

# %%
model = smf.ols(model_parameter, Auto).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):          2.04e-139
# Time:                        12:31:09   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      -17.2184      4.644     -3.707      0.000     -26.350      -8.087
# ...

# %%
table = sm.stats.anova_lm(model)
print(table)
# Out:
#                  df        sum_sq       mean_sq            F         PR(>F)
# cylinders       1.0  14403.083079  14403.083079  1300.683788  2.319511e-125
# displacement    1.0   1073.344025   1073.344025    96.929329   1.530906e-20
# horsepower      1.0    403.408069    403.408069    36.430140   3.731128e-09
# weight          1.0    975.724953    975.724953    88.113748   5.544461e-19
# acceleration    1.0      0.966071      0.966071     0.087242   7.678728e-01
# year            1.0   2419.120249   2419.120249   218.460900   1.875281e-39
# origin          1.0    291.134494    291.134494    26.291171   4.665681e-07
# Residual      384.0   4252.212530     11.073470          NaN            NaN

# %% [markdown]
# **ii** $\text{Which predictors appear to have a statistically significant relationship to the response?}$

# %% [markdown]
# ##### $\text{displacement, weight, year and origin (p<0.05)}$

# %% [markdown]
# **iii** $\text{What does the coefficient for the \textcolor{145, 75, 40}{year} variable suggest?}$

# %% [markdown]
# ##### $\text{If all other variables are held constant, one unit increment of \textcolor{145, 75, 40}{year} increments mpg amount 0.75 }$

# %% [markdown]
# #### $\text{(d) Produce some of diagnostic plots of the linear regression fit as described in the lab. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?}$

# %%
diag = LinearRegDiagnostic(model)
plt.clf()
print(diag.vif_table())
diag.scale_location_plot()
diag.qq_plot()
diag.leverage_plot()
diag.residual_plot()
# Out:
#        Features  VIF Factor
# 6          year        1.24
# 7        origin        1.77
# 5  acceleration        2.63
# 3    horsepower        9.94
# 1     cylinders       10.74
# 4        weight       10.83
# 2  displacement       21.84
# 0     Intercept      763.56
# <Axes: title={'center': 'Residuals vs Fitted'}, xlabel='Fitted values', ylabel='Residuals'>

# %% [markdown]
# $\begin{document}
# \text{ No, there are no unusually large outliers, as per the the scale log location. They are however skewedly distributed. The larger the fitted value, the larger the variance, since the spread of the residuals increases.\\ No, even though there is an observation (number 13) with higher leverage, it is still well within Cook's 0.5 distance. \\ The normal qq-plot deviates at one extreme, which could indicate that there are other explanatory predictors that we are not considering (quadratic terms, for example). Additionally, the funnel shape of the residuals plot indicates heteroskedacity.}
# \end{document}$

# %% [markdown]
# #### $\text{(e) Fit some models with interactions as described in the lab. Do any interactions appear to be statistically significant?}$

# %%
import itertools

new_columns = result = [item for item in columns if item not in ["cylinders","acceleration"]]


formatted_list = [f"{a}*{b}" for a, b in itertools.permutations(new_columns, 2)]
formatted_list
# Out:
# ['displacement*horsepower',
#  'displacement*weight',
#  'displacement*year',
#  'displacement*origin',
#  'horsepower*displacement',
#  'horsepower*weight',
#  'horsepower*year',
#  'horsepower*origin',
#  'weight*displacement',
#  'weight*horsepower',
#  'weight*year',
#  'weight*origin',
#  'year*displacement',
#  'year*horsepower',
#  'year*weight',
#  'year*origin',
#  'origin*displacement',
#  'origin*horsepower',
#  'origin*weight',
#  'origin*year']

# %%
model_parameter = "mpg~"+"+".join(formatted_list)
model = smf.ols(model_parameter, Auto).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     184.0
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):          1.09e-162
# Time:                        12:31:10   Log-Likelihood:                -945.49
# No. Observations:                 392   AIC:                             1923.
# Df Residuals:                     376   BIC:                             1987.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                 -51.3746     26.175     -1.963      0.050    -102.843       0.093
# ...

# %% [markdown]
# #### $\text{(f) Try a few different transformations of the variables, such as \log{X}, \sqrt{X}, X^2. Comment on your findings.}$

# %%
tranformed_parameters="mpg ~ horsepower + np.power(horsepower,2) + np.log(horsepower) +np.sqrt(horsepower) + weight + year + origin"
model = smf.ols(tranformed_parameters, Auto).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     332.9
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):          9.16e-159
# Time:                        12:31:10   Log-Likelihood:                -977.89
# No. Observations:                 392   AIC:                             1972.
# Df Residuals:                     384   BIC:                             2004.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                -426.3991    167.288     -2.549      0.011    -755.314     -97.485
# ...

# %%
### Q10

# %% [markdown]
# ### Q10

# %% [markdown]
# #### $\text{10. This question should be answered using the \textcolor{145, 75, 40}{Carseats} data set.}$

# %% [markdown]
# #### $\text{(a) Fit a multiple regression model to predict \textcolor{145, 75, 40}{Sales} using \textcolor{145, 75, 40}{Price}, \textcolor{145, 75, 40}{Urban}, and \textcolor{145, 75, 40}{US}.}$

# %%
Carseats = load_data("Carseats")
Carseats
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
Carseats.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
Carseats.nunique()
# Out:
# Sales          336
# CompPrice       73
# Income          98
# Advertising     28
# Population     275
# Price          101
# ShelveLoc        3
# Age             56
# Education        9
# Urban            2
# US               2
# dtype: int64

# %%
model_a = smf.ols("Sales ~ Price + Urban + US", data=Carseats).fit()
model_a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           2.39e-23
# Time:                        12:31:10   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### $\text{(b) Provide an interpretation of each coefficient in the model. Be careful—some of the variables in the model are qualitative!}$

# %% [markdown]
# ##### $\text{Summary shows that Urban is a qualitative parameter and not significant variable (p-value is not < 0.05) US is qualitative parameter and its a significant variable. If the store is in US, it tends to sell 1.2 unit (I said unit because probably sales parameter is normalized or simplified in order to get rid of unnecessary zeros) more than the ones who are not located in US) Price is a quantitative parameter and its negatively related which means if one unit increment in price causes 0.05 unit reduction in sales} $

# %% [markdown]
# #### $\text{(c) Write out the model in equation form, being careful to handle the qualitative variables properly.}$

# %% [markdown]
# \begin{equation*}
# \begin{aligned}
#     \text{Sales} &= 13.0435 - 0.0219 \times \text{Urban} + 1.2006 \times \text{US} - 0.0545 \times \text{Price} \\
#     &= \left\{
#     \begin{array}{ll}
#     13.0435 - 0.0219 \times \text{Urban} + 1.2006 \times \text{US} - 0.0545 \times \text{Price} & \text{Urban = 1, US = 1} \\
#     13.0435 - 0.0219 \times \text{Urban} + 1.2006 \times \text{Price} & \text{Urban = 1, US = 0} \\
#     13.0435 + 1.2006 \times \text{US} - 0.0545 \times \text{Price} & \text{Urban = 0, US = 1} \\
#     13.0435 - 0.0545 \times \text{Price} & \text{Urban = 0, US = 0}
#     \end{array}
#     \right.
# \end{aligned}
# \end{equation*}

# %% [markdown]
# #### $\text{(d) For which of the predictors can you reject the null hypothesis } H_0 : \beta_j = 0?$

# %% [markdown]
# ##### $\text{As we describe in part b, while US and and Price values can reject the null hypothesis we cannot reject for Urban parameter}$

# %% [markdown]
# #### $\text{(e) On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.}$

# %%
model_e = smf.ols("Sales ~ Price + US", data=Carseats).fit()
model_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           2.66e-24
# Time:                        12:31:10   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...

# %% [markdown]
# #### $\text{(f) How well do the models in (a) and (e) fit the data?}$

# %% [markdown]
# ##### $\text{When we look R^2 values for both models, It seems that model scores are almost equal. Therefore we can state that simpler model is better in order to be able to reach the same scores with less parameter}$

# %% [markdown]
# #### $\text{(g) Using the model from (e), obtain 95\% confidence intervals for the coefficient(s).}$

# %% [markdown]
# ##### $\text{According to book, 95\% confidence intervals for the coefficients is}$
# $$
# \hat{\beta_i} - 2 \times SE(\hat{\beta_i})
# $$
# ##### $\text{Therefore, we will calculate following}$

# %%
intercept_coef = 13.0308
intercept_stderr = .631

us_coef = 1.1996
us_stderr = .258

price_coef = -.0545
price_stderr = .005

print('95%% confidence interval for Intercept: [ %2.4f; %2.4f] ' % (intercept_coef-2*intercept_stderr, intercept_coef+2*intercept_stderr))
print('95%% confidence interval for Intercept: [ %2.4f; %2.4f] ' % (us_coef-2*us_stderr, us_coef+2*us_stderr))
print('95%% confidence interval for Intercept: [ %2.4f; %2.4f] ' % (price_coef-2*price_stderr, price_coef+2*price_stderr))
# Out:
# 95% confidence interval for Intercept: [ 11.7688; 14.2928]
# 95% confidence interval for Intercept: [ 0.6836; 1.7156]
# 95% confidence interval for Intercept: [ -0.0645; -0.0445]

# %% [markdown]
# #### $\text{(h) Is there evidence of outliers or high leverage observations in the model from (e)?}$

# %%
cls_h = LinearRegDiagnostic(model_e)

# %%
cls_h.vif_table()
cls_h.scale_location_plot()
cls_h.leverage_plot()
cls_h.residual_plot()
# Out:
# <Axes: title={'center': 'Residuals vs Fitted'}, xlabel='Fitted values', ylabel='Residuals'>

# %% [markdown]
# ##### $\text{Seems there is no any outlier}$

# %% [markdown]
# ### Q11

# %% [markdown]
# #### $\text{11. In this problem we will investigate the t-statistic for the null hypothesis } H_0 : \beta = 0 \text{ in simple linear regression without an intercept. To begin, we generate a predictor } x \text{ and a response } y \text{ as follows.}$

# %%
rng = np.random.default_rng(1)
x = rng.normal(size =100)
y = 2 * x + rng.normal(size =100)

# %% [markdown]
# #### $\text{(a) Perform a simple linear regression of } y \text{ onto } x, \text{ without an intercept. Report the coefficient estimate } \hat{\beta}, \text{ the standard error of this coefficient estimate, and the t-statistic and p-value associated with the null hypothesis } H_0 : \beta = 0. \text{ Comment on these results. (You can perform regression without an intercept using the keywords argument intercept=False to ModelSpec().)}$

# %%
df = pd.DataFrame({'x': x, 'y': y})
model_a = smf.ols("y ~ x + 0", data=df).fit()
model_a.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):                    6.23e-31
# Time:                        12:31:10   Log-Likelihood:                         -141.35
# No. Observations:                 100   AIC:                                      284.7
# Df Residuals:                      99   BIC:                                      287.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x='x', y='y', data=df)
plt.show()

# %% [markdown]
# #### $\text{(b) Now perform a simple linear regression of } x \text{ onto } y \text{ without an intercept, and report the coefficient estimate, its standard error, and the corresponding t-statistic and p-values associated with the null hypothesis } H_0 : \beta = 0. \text{ Comment on these results.}$

# %%
model_b = smf.ols("x ~ y + 0", data=df).fit()
model_b.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      x   R-squared (uncentered):                   0.743
# Model:                            OLS   Adj. R-squared (uncentered):              0.740
# Method:                 Least Squares   F-statistic:                              285.6
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):                    6.23e-31
# Time:                        12:31:10   Log-Likelihood:                         -58.349
# No. Observations:                 100   AIC:                                      118.7
# Df Residuals:                      99   BIC:                                      121.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### $\text{(c) What is the relationship between the results obtained in (a) and (b)?}$

# %% [markdown]
# ##### $\text{t statistics are same but errors are different and also \hat{\beta_y} \neq \frac{1}{\hat{\beta_x}}}. The reason behind the inequality is that the loss function is not symmetric. Which means we are not calculating the same loss.$

# %%
# Plotting the data with horizontal residual lines for Model B and vertical residual lines for Model A
plt.clf()
plt.figure(figsize=(12, 6))

# Plot for Model A (y ~ x + 0)
plt.subplot(1, 2, 1)
plt.scatter(df['x'], df['y'], color='blue', alpha=0.5, label="Data points")
plt.plot(df['x'], model_a.fittedvalues, color='red', label=f"Regression line (y ~ x), β_x = {model_a.params[0]:.2f}")
# Drawing vertical lines from points to the regression line (residuals)
for i in range(len(df)):
    plt.plot([df['x'][i], df['x'][i]], [df['y'][i], model_a.fittedvalues[i]], color='orange', alpha=0.5)
plt.title("Regression of y on x")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Plot for Model B (x ~ y + 0) - Reverted
plt.subplot(1, 2, 2)
plt.scatter(df['x'], df['y'], color='blue', alpha=0.5, label="Data points")
plt.plot(model_b.fittedvalues,df['y'], color='green', label=f"Regression line (x ~ y), β_y = {model_b.params[0]:.2f}")
# Drawing horizontal lines from points to the regression line (residuals)
for i in range(len(df)):
    plt.plot([model_b.fittedvalues[i], df['x'][i]], [df['y'][i], df['y'][i]], color='purple', alpha=0.5)
plt.title("Regression of x on y")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /var/folders/6r/cs7m9yw905q4n_v543s39ddh0000gn/T/ipykernel_956/2138903517.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(df['x'], model_a.fittedvalues, color='red', label=f"Regression line (y ~ x), β_x = {model_a.params[0]:.2f}")
# /var/folders/6r/cs7m9yw905q4n_v543s39ddh0000gn/T/ipykernel_956/2138903517.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.plot(model_b.fittedvalues,df['y'], color='green', label=f"Regression line (x ~ y), β_y = {model_b.params[0]:.2f}")

# %% [markdown]
# ##### $\text{When we flip the x on y plot we can see that the loss values are different (least squares are not symmetric) and therefore, the beta values are not reciprocals of each other.  }$

# %% [markdown]
# #### $\text{(d) For the regression of } Y \text{ onto } X \text{ without an intercept, the t-statistic for } H_0 : \beta = 0 \text{ takes the form } \hat{\beta} / SE(\hat{\beta}), \text{ where } \hat{\beta} \text{ is given by (3.38), and where}$
# #### $\text{SE(\hat{\beta}) = \sqrt{\frac{\sum_{i=1}^{n} (y_i - x_i \hat{\beta})^2}{(n-1) \sum_{i=1}^{n} x_i^2}}}$
# #### $\text{(These formulas are slightly different from those given in Sections 3.1.1 and 3.1.2, since we are performing regression without an intercept.) Show algebraically, and confirm numerically in R, that the t-statistic can be written as}$
# #### $\text{ \frac{\sqrt{n-1} \sum_{i=1}^{n} x_i y_i}{\sqrt{(\sum_{i=1}^{n} x_i^2 (\sum_{i=1}^{n} y_i^2) - (\sum_{i=1}^{n} x_i y_i)^2}}}$

# %% [markdown]
# ##### $\text{To not be overwhelmed by parameters, lets simplify as}$
# $$
# a = \sum_{i=1}^{n} y_i^2
# $$
# $$
# b = \beta
# $$
# $$
# c = \sum_{i=1}^{n} (y_i \cdot x_i)
# $$
# $$
# d = \sum_{i=1}^{n} x_i^2
# $$
# $$
# e = n-1
# $$
#
# $\text{Then,}$
#
# $$
# \beta = \frac{c}{d} = b
# $$
# $$
# SE(\beta) = \frac{\sqrt{a - 2 \cdot b \cdot c + b^2 \cdot d}}{\sqrt{e \cdot d}}
# $$
#
# Now, question says, prove that:
#
# $$
# \frac{\frac{c}{d}}{\frac{\sqrt{a - 2 \cdot b \cdot c + b^2 \cdot d}}{\sqrt{e \cdot d}}} = \frac{\sqrt{e} \cdot c}{\sqrt{d \cdot a - c^2}}
# $$
#
# If we do following operations:
#
# $$
# \frac{\frac{c}{d}}{\frac{\sqrt{a - 2 \cdot b \cdot c + b^2 \cdot d}}{\sqrt{e \cdot d}}} = \frac{c \cdot \sqrt{e} \cdot \cancel{\sqrt{d}}}{(\sqrt{d} \cdot  \cancel{\sqrt{d}})  \sqrt{a - 2 \cdot b \cdot c + b^2 \cdot d}} = \frac{c \cdot \sqrt{e} }{ \sqrt{a \cdot d - 2b \cdot c \cdot d + b^2 \cdot d^2}}
# $$
# $\text{We know that b = \frac{c}{d} Thus, the result will be:}$
# $$
# \frac{c \cdot \sqrt{e} }{ \sqrt{a \cdot d - 2c^2 + c^2}} = \frac{c \cdot \sqrt{e} }{ \sqrt{a \cdot d - c^2}} = \frac{\sqrt{e} \cdot c}{\sqrt{d \cdot a - c^2}}
# $$
#
# $\text{Which is what the question ask us.}$

# %% [markdown]
# #### $\text{(e) Using the results from (d), argue that the t-statistic for the regression of y onto x is the same as the t-statistic for the regression of x onto y.}$

# %% [markdown]
# ##### $\text{t-statistic is symmetric for x and y. Therefore this score will be same whether it is x onto y or vice versa.}$

# %% [markdown]
# #### $\text{(f) In R, show that when regression is performed with an intercept, the t-statistic for } H_0 : \beta_1 = 0 \text{ is the same for the regression of } y \text{ onto } x \text{ as it is for the regression of } x \text{ onto } y.$

# %% [markdown]
# ##### $\text{I think there was a typo here because the book was probably created in R language and then edited in Python. We have already shown above (part a-b). But let's show again}$

# %%
print(model_a.tvalues)
print(model_b.tvalues)
# Out:
# x    16.898417
# dtype: float64
# y    16.898417
# dtype: float64

# %% [markdown]
# ### Q12

# %% [markdown]
# #### $\text{12. This problem involves simple linear regression without an intercept.}$

# %% [markdown]
# #### $\text{(a) Recall that the coefficient estimate } \hat{\beta} \text{ for the linear regression of } Y \text{ onto } X \text{ without an intercept is given by (3.38). Under what circumstance is the coefficient estimate for the regression of X onto Y the same as the coefficient estimate for the regression of Y onto X?}$

# %% [markdown]
# ##### $\text{We already discussed in one of the previous questions. We know that}$
#
# $$
# \hat{\beta_x} = \frac{\sum_{i=1}^{n} (y_i \cdot x_i)}{\sum_{i=1}^{n} x_i^2}
# $$
# $$
# \hat{\beta_y} = \frac{\sum_{i=1}^{n} (y_i \cdot x_i)}{\sum_{i=1}^{n} y_i^2}
# $$
#
# ##### $\text{Therefore, when $\sum_{i=1}^{n} x_i^2$ = $\sum_{i=1}^{n} y_i^2$, the coefficient estimate for the regression of X onto Y the same as the coefficient estimate for the regression of Y onto X}$

# %% [markdown]
# #### $\text{(b) Generate an example in \textcolor{145, 75, 40}{Python} with } n = 100 \text{ observations in which the coefficient estimate for the regression of X onto Y is different from the coefficient estimate for the regression of Y onto X.}$

# %% [markdown]
# ##### $\text{In all examples except y=x, coefficients will be different}$

# %%
x = np.arange(100)
y = 2*x

model_x = sm.OLS(y,x).fit()
print(model_x.params[0])
model_y = sm.OLS(x,y).fit()
print(model_y.params[0])
# Out:
# 1.9999999999999991
# 0.4999999999999998

# %% [markdown]
# #### $\text{(c) Generate an example in \textcolor{145, 75, 40}{Python} with } n = 100 \text{ observations in which the coefficient estimate for the regression of X onto Y is the same as the coefficient estimate for the regression of Y onto X.}$

# %%
x = np.arange(100)
y = x

model_x = sm.OLS(y,x).fit()
print(model_x.params[0])
model_y = sm.OLS(x,y).fit()
print(model_y.params[0])
# Out:
# 0.9999999999999996
# 0.9999999999999996

# %% [markdown]
# ### Q13

# %% [markdown]
# #### $\text{13. In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use the default random number generator with seed set to 1 prior to starting part (a) to ensure consistent results.}$

# %% [markdown]
# #### $\text{(a) Using the normal() method of your random number generator, create a vector, } x, \text{ containing 100 observations drawn from a } N(0,1) \text{ distribution. This represents a feature, X.}$

# %%
rng = np.random. default_rng (1)
x = rng.normal(loc=0, scale=1, size=100)

# %% [markdown]
# #### $\text{(b) Using the normal() method, create a vector, eps, containing 100 observations drawn from a } N(0, 0.25) \text{ distribution—a normal distribution with mean zero and variance 0.25.}$

# %%
eps = rng.normal(loc=0, scale=0.25, size=100)

# %% [markdown]
# #### $\text{(c) Using } x \text{ and } \epsilon, \text{ generate a vector } y \text{ according to the model}$
#
# #### $Y = -1 + 0.5X + \epsilon$  $(3.39)$
#
# #### $\text{What is the length of the vector } y? \text{ What are the values of } \beta_0 \text{ and } \beta_1 \text{ in this linear model?}$

# %%
y=-1 + 0.5*x + eps
print("Lengt of y is", len(y))
print("B_0 value is -1")
print("B_1 value is 0.5")
# Out:
# Lengt of y is 100
# B_0 value is -1
# B_1 value is 0.5

# %% [markdown]
# #### $\text{(d) Create a scatterplot displaying the relationship between } x \text{ and } y. \text{ Comment on what you observe.}$

# %%
sns.jointplot(x=x, y=y);

# %% [markdown]
# #### $\text{(e) Fit a least squares linear model to predict } y \text{ using } x. \text{ Comment on the model obtained. How do } \hat{\beta}_0 \text{ and } \hat{\beta}_1 \text{ compare to } \beta_0 \text{ and } \beta_1?$

# %%
df = pd.DataFrame({'x':x, 'y':y})
model_e = smf.ols("y ~ x", df).fit()
model_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     280.0
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           1.74e-30
# Time:                        12:31:11   Log-Likelihood:                -2.4306
# No. Observations:                 100   AIC:                             8.861
# Df Residuals:                      98   BIC:                             14.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0190      0.025    -40.537      0.000      -1.069      -0.969
# ...

# %% [markdown]
# #### $\text{(f) Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the legend() method of the axes to create an appropriate legend.}$

# %%
# Plot the scatterplot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='x', y='y', data=df, color='blue', label="Data points")

# Use model_e's coefficients to calculate the OLS regression line
ols_line = model_e.fittedvalues
plt.plot(df['x'], ols_line, color='red', label="OLS Regression Line (from model_e)")


# Add the population regression line (y = 2x)
plt.plot(np.linspace(df.x.min(), df.x.max(), 100), -1 + 0.5 * np.linspace(df.x.min(), df.x.max(), 100), color='green', label="Population Regression Line")

# Add title and labels
plt.title("Scatterplot with OLS and Population Regression Lines")
plt.xlabel("x")
plt.ylabel("y")

# Show legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# #### $\text{(g) Now fit a polynomial regression model that predicts } y \text{ using } x \text{ and } x^2. \text{ Is there evidence that the quadratic term improves the model fit? Explain your answer.}$

# %%
model_g = smf.ols("y ~ x + I(x**2)", df).fit()
model_g.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     138.6
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           3.66e-29
# Time:                        12:31:11   Log-Likelihood:                -2.4293
# No. Observations:                 100   AIC:                             10.86
# Df Residuals:                      97   BIC:                             18.67
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0182      0.030    -34.186      0.000      -1.077      -0.959
# ...

# %% [markdown]
# ##### $\text{We see that p value for square term is 0.959 which states we cannot reject null hypothesis for squared term. Also it is clearly seen that R^2 scores are same for both model}$

# %% [markdown]
# #### $\text{(h) Repeat (a)-(f) after modifying the data generation process in such a way that there is less noise in the data. The model (3.39) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term } \epsilon \text{ in (b). Describe your results.}$

# %%
eps = rng.normal(loc=0, scale=0.01, size=100)
y=-1 + 0.5*x + eps
print("Lengt of y is", len(y))
print("B_0 value is -1")
print("B_1 value is 0.5")
# Out:
# Lengt of y is 100
# B_0 value is -1
# B_1 value is 0.5

# %%
sns.jointplot(x=x, y=y);

# %%
df = pd.DataFrame({'x':x, 'y':y})
model_h = smf.ols("y ~ x", df).fit()
model_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.130e+05
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):          2.37e-165
# Time:                        12:31:11   Log-Likelihood:                 327.72
# No. Observations:                 100   AIC:                            -651.4
# Df Residuals:                      98   BIC:                            -646.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0016      0.001  -1081.956      0.000      -1.003      -1.000
# ...

# %%
# Plot the scatterplot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='x', y='y', data=df, color='blue', label="Data points")

# Use model_e's coefficients to calculate the OLS regression line
ols_line = model_h.fittedvalues
plt.plot(df['x'], ols_line, color='red', label="OLS Regression Line (from model_e)")


# Add the population regression line (y = 2x)
plt.plot(np.linspace(df.x.min(), df.x.max(), 100), -1 + 0.5 * np.linspace(df.x.min(), df.x.max(), 100), color='green', label="Population Regression Line")

# Add title and labels
plt.title("Scatterplot with OLS and Population Regression Lines")
plt.xlabel("x")
plt.ylabel("y")

# Show legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ##### $\text{Less noise causes model to fit more properly. Beta parameters are almost correct and R^2 score is 1.000}$

# %% [markdown]
# #### $\text{(i) Repeat (a)-(f) after modifying the data generation process in such a way that there is more noise in the data. The model (3.39) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term } \epsilon \text{ in (b). Describe your results.}$

# %%
eps = rng.normal(loc=0, scale=10, size=100)
y=-1 + 0.5*x + eps
print("Lengt of y is", len(y))
print("B_0 value is -1")
print("B_1 value is 0.5")
# Out:
# Lengt of y is 100
# B_0 value is -1
# B_1 value is 0.5

# %%
sns.jointplot(x=x, y=y);

# %%
df = pd.DataFrame({'x':x, 'y':y})
model_i = smf.ols("y ~ x", df).fit()
model_i.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     3.707
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):             0.0571
# Time:                        12:31:11   Log-Likelihood:                -357.37
# No. Observations:                 100   AIC:                             718.7
# Df Residuals:                      98   BIC:                             723.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0916      0.875     -1.248      0.215      -2.827       0.644
# ...

# %%
# Plot the scatterplot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='x', y='y', data=df, color='blue', label="Data points")

# Use model_e's coefficients to calculate the OLS regression line
ols_line = model_i.fittedvalues
plt.plot(df['x'], ols_line, color='red', label="OLS Regression Line (from model_e)")


# Add the population regression line (y = 2x)
plt.plot(np.linspace(df.x.min(), df.x.max(), 100), -1 + 0.5 * np.linspace(df.x.min(), df.x.max(), 100), color='green', label="Population Regression Line")

# Add title and labels
plt.title("Scatterplot with OLS and Population Regression Lines")
plt.xlabel("x")
plt.ylabel("y")

# Show legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ##### $\text{When noise is too much, R^2 score is drammatically decreased. Even p value for x is bigger than 0.05. Because the noise is so much that x cannot explain the dataset}$

# %% [markdown]
# #### $\text{(j) What are the confidence intervals for } \beta_0 \text{ and } \beta_1 \text{ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.}$

# %%
print("First model: ")
print(model_e.conf_int(alpha=0.05, cols=None))
print("------------")
print("Less Noide model: ")
print(model_h.conf_int(alpha=0.05, cols=None))
print("------------")
print("More Noise model: ")
print(model_i.conf_int(alpha=0.05, cols=None))
# Out:
# First model:
#                   0         1
# Intercept -1.068891 -0.969122
# x          0.433783  0.550508
# ------------
# Less Noide model:
#                   0         1
# Intercept -1.003456 -0.999782
# x          0.497723  0.502022
# ------------
# More Noise model:
#                   0         1
# Intercept -2.827108  0.643930
# x         -0.060538  4.000426

# %% [markdown]
# ##### $\text{The gap between upper and lower limit of confidence interval at 95 \% is bigger when noise is bigger.}$

# %% [markdown]
# ### Q14

# %% [markdown]
# #### $\text{14. This problem focuses on the collinearity problem.}$

# %% [markdown]
# #### $\text{(a) Perform the following commands in Python:}$

# %%
rng = np.random.default_rng(10)
x1 = rng.uniform(0, 1, size=100)
x2 = 0.5 * x1 + rng.normal(size=100) / 10
y = 2 + 2 * x1 + 0.3 * x2 + rng.normal(size=100)

# %% [markdown]
# #### $\text{The last line corresponds to creating a linear model in which } y \text{ is a function of } x_1 \text{ and } x_2. \text{ Write out the form of the linear model. What are the regression coefficients?}$

# %% [markdown]
# ##### $Y = \beta_0 + \beta_1 X_1 + \beta_2 X_2 + \epsilon = 2 + 2X_1 + 0.3X_2 + \epsilon$

# %% [markdown]
# #### $\text{(b) What is the correlation between } x_1 \text{ and } x_2? \text{ Create a scatterplot displaying the relationship between the variables.}$

# %%
df = pd.DataFrame({'x1':x1,'x2':x2,'y':y})
df.corr()
# Out:
#           x1        x2         y
# x1  1.000000  0.772324  0.530531
# x2  0.772324  1.000000  0.471356
# y   0.530531  0.471356  1.000000

# %%
plt.scatter(x1,x2)

# %% [markdown]
# #### $\text{(c) Using this data, fit a least squares regression to predict  y  using  x_1 and x_2. Describe the results obtained. What are  \hat{\beta_0}, \hat{\beta_1}, and \hat{\beta_2}? Can you reject the null hypothesis H_0 : \beta_1 = 0?  How about the null hypothesis H_0 : \beta_2 = 0?}$

# %%
model_c = smf.ols("y ~ x1 + x2", data=df).fit()
model_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     19.89
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           5.76e-08
# Time:                        12:31:11   Log-Likelihood:                -130.62
# No. Observations:                 100   AIC:                             267.2
# Df Residuals:                      97   BIC:                             275.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9579      0.190     10.319      0.000       1.581       2.334
# ...

# %% [markdown]
# ##### $\text{x1 is a significant variable so we can reject null hypothesis. However, x2 is not effective parameter for data. Moreover, Even though the real coeficient of x1 is 2, the model found it as 1.6. }$

# %% [markdown]
# #### $\text{(d) Now fit a least squares regression to predict } y \text{ using only } x1. \text{ Comment on your results. Can you reject the null hypothesis } H_0 : \beta_1 = 0?$

# %%
model_d = smf.ols("y ~ x1", data=df).fit()
model_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     38.39
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           1.37e-08
# Time:                        12:31:11   Log-Likelihood:                -131.28
# No. Observations:                 100   AIC:                             266.6
# Df Residuals:                      98   BIC:                             271.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9371      0.189     10.242      0.000       1.562       2.312
# ...

# %% [markdown]
# ##### $\text{R^2 score is decreased but the coefficient value of x_1 is increased. Still we can reject the null hypothesis for x_1}$

# %% [markdown]
# #### $\text{(e) Now fit a least squares regression to predict } y \text{ using only } x2. \text{ Comment on your results. Can you reject the null hypothesis } H_0 : \beta_1 = 0?$

# %%
model_e = smf.ols("y ~ x2", data=df).fit()
model_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     27.99
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           7.43e-07
# Time:                        12:31:11   Log-Likelihood:                -135.24
# No. Observations:                 100   AIC:                             274.5
# Df Residuals:                      98   BIC:                             279.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.3239      0.154     15.124      0.000       2.019       2.629
# ...

# %% [markdown]
# ##### $\text{R^2 score is decreased but the coefficient value of x_2 is increased. This time we can reject the null hypothesis for x_2}$

# %% [markdown]
# #### $\text{(f) Do the results obtained in (c)-(e) contradict each other? Explain your answer.}$

# %% [markdown]
# ##### $\text{Results may seem confusing but there is no contradiction. The reason for this confusion is called collinearity. It states that if some of parameters are related to each other, model will use only one of them because the data can be explained by only using one of them.}$

# %% [markdown]
# #### $\text{(g) Suppose we obtain one additional observation, which was unfortunately mismeasured. We use the function } np.concatenate() \text{ to add this additional observation to each of } x1, x2, \text{ and } y.$

# %%
x1 = np.concatenate([x1, [0.1]])
x2 = np.concatenate([x2, [0.8]])
y = np.concatenate([y, [6]])

# %% [markdown]
# #### $\text{Re-fit the linear models from (c)-(e) using this new data. What effect does this new observation have on the each of the models? In each model, is this observation an outlier? A high-leverage point? Both? Explain your answers.}$

# %%
df = pd.DataFrame({'x1':x1,'x2':x2,'y':y})

# %%
model_c = smf.ols("y ~ x1 + x2", data=df).fit()
model_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.292
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     20.17
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           4.60e-08
# Time:                        12:31:11   Log-Likelihood:                -135.30
# No. Observations:                 101   AIC:                             276.6
# Df Residuals:                      98   BIC:                             284.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0618      0.192     10.720      0.000       1.680       2.443
# ...

# %%
model_d = smf.ols("y ~ x1", data=df).fit()
model_d.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.217
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     27.42
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           9.23e-07
# Time:                        12:31:11   Log-Likelihood:                -140.37
# No. Observations:                 101   AIC:                             284.7
# Df Residuals:                      99   BIC:                             290.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0739      0.201     10.310      0.000       1.675       2.473
# ...

# %%
model_e = smf.ols("y ~ x2", data=df).fit()
model_e.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     36.10
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           3.13e-08
# Time:                        12:31:11   Log-Likelihood:                -137.01
# No. Observations:                 101   AIC:                             278.0
# Df Residuals:                      99   BIC:                             283.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2840      0.151     15.088      0.000       1.984       2.584
# ...

# %% [markdown]
# ##### $\text{While R^2 score of model_d is decreased significantly, others increased slightly}. The reason of this change is that the new sample is different from others$

# %%
plt.scatter(x1[:-1],y[:-1])
plt.scatter(x1[-1:],y[-1:], color='red')

# %% [markdown]
# ### Q15

# %%
plt.scatter(x2[:-1],y[:-1])
plt.scatter(x2[-1:],y[-1:], color='red')

# %% [markdown]
# ##### $\text{When we look at x1 / y and x2 / y plots, the new sample looks in range of the data. Like it is a high leverage but not an outlier. }$

# %%
plt.scatter(x1[:-1],x2[:-1])
plt.scatter(x1[-1:],x2[-1:], color='red')

# %% [markdown]
# ##### $\text{New data seems it is an outlier when we look at x1 / x2 plot because even though the values of x1 and x2 of new sample is in the data interval, combination of x1 and x2 is different than the others in data}$

# %%
cls = LinearRegDiagnostic(model_d)
cls.vif_table()
cls.scale_location_plot()
cls.leverage_plot()
cls.residual_plot()
# Out:
# <Axes: title={'center': 'Residuals vs Fitted'}, xlabel='Fitted values', ylabel='Residuals'>

# %% [markdown]
# #### $\text{15. This problem involves the \textcolor{145, 75, 40}{Boston} data set, which we saw in the lab for this chapter. We will now try to predict per capita crime rate using the other variables in this data set. In other words, per capita crime rate is the response, and the other variables are the predictors.}$

# %% [markdown]
# #### $\text{(a) For each predictor, fit a simple linear regression model to predict the response. Describe your results. In which of the models is there a statistically significant association between the predictor and the response? Create some plots to back up your assertions.}$

# %%
Boston = load_data("Boston")
Boston
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  lstat  medv
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# 2       17.8   4.03  34.7
# ...

# %%
predictors = [c for c in Boston.columns if c not in ["crim"]]
plt.figure(figsize=(20, 20))

for i, predictor in enumerate(predictors):
    model = 'crim ~ ' + predictor
    res = smf.ols(formula = model, data=Boston).fit()
    plt.subplot(5,3,i+1)
    plt.xlabel(predictor)
    plt.ylabel("crim")
    plt.scatter(Boston[predictor], Boston['crim'])
    plt.plot(Boston[predictor], res.fittedvalues, color='red')

# %% [markdown]
# #### $\text{(b) Fit a multiple regression model to predict the response using all of the predictors. Describe your results. For which predictors can we reject the null hypothesis } H_0 : \beta_j = 0?$

# %%
all_columns = "+".join([c for c in Boston.columns if c not in ["crim"]])
model = " crim ~ " + all_columns
res = smf.ols(formula = model, data=Boston).fit()
print(res.summary())
print(model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.436
# Method:                 Least Squares   F-statistic:                     33.52
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           2.03e-56
# Time:                        12:31:12   Log-Likelihood:                -1655.4
# No. Observations:                 506   AIC:                             3337.
# Df Residuals:                     493   BIC:                             3392.
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.7784      7.082      1.946      0.052      -0.136      27.693
# ...

# %% [markdown]
# ##### $\text{When we look at p values < 0.05, zn, nox, dis, rad and medv parameters can reject the null hpyothesis. Also the function warns us that there are some multicollinearities in the parameters}$

# %% [markdown]
# #### $\text{(c) How do your results from (a) compare to your results from (b)? Create a plot displaying the univariate regression coefficients from (a) on the x-axis, and the multiple regression coefficients from (b) on the y-axis. That is, each predictor is displayed as a single point in the plot. Its coefficient in a simple linear regression model is shown on the x-axis, and its coefficient estimate in the multiple linear regression model is shown on the y-axis.}$

# %%
coefs = {}
for predictor in predictors:
    model = 'crim ~ ' + predictor
    resx = smf.ols(formula = model, data=Boston).fit()
    coefs[predictor] = [resx.params[predictor]] 
for predictor in predictors:
    coefs[predictor].append(res.params[predictor])

plt.scatter([coefs[pred][0] for pred in coefs], [coefs[pred][1] for pred in coefs])
plt.plot([-5,35],[-5,35]) # plot y=x
for predictor in coefs:
    plt.annotate(predictor, (coefs[predictor][0], coefs[predictor][1]), textcoords="offset points", xytext=(0, 10), ha='center')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ##### $\text{nox value is prevent to analyse. Let's remove it}$

# %%
plt.scatter([coefs[pred][0] for pred in coefs if pred != "nox"], [coefs[pred][1] for pred in coefs if pred != "nox"])
plt.plot([-3,1], [-3,1]) # plot y=x
for predictor in coefs:
    plt.annotate(predictor, (coefs[predictor][0], coefs[predictor][1]), textcoords="offset points", xytext=(0, 10), ha='center')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %% [markdown]
# ##### $\text{According to these two plots, we saw that value "nox" has definitely related to one of the variables because its single model and multinear model coefficient is very different. Also ptratio and rm can be defined as "collinear" with others but they are not much like nox parameter}$

# %% [markdown]
# #### $\text{(d) Is there evidence of non-linear association between any of the predictors and the response? To answer this question, for each predictor X, fit a model of the form}$
#
# #### $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + \beta_3 X^3 + \epsilon $$

# %%
predictors = [c for c in Boston.columns if c not in ["crim"]]
plt.figure(figsize=(20, 20))

for i, predictor in enumerate(predictors):
    model = 'crim ~ ' + predictor + "+ I(" + predictor + "**2)" + "+ I(" + predictor + "**3)"
    res = smf.ols(formula = model, data=Boston).fit()
    plt.subplot(5,3,i+1)
    plt.xlabel(predictor)
    plt.ylabel("crim")
    plt.scatter(Boston[predictor], Boston['crim'])
    x = np.linspace(min(Boston[predictor]),max(Boston[predictor]), 100)
    y = res.params.iloc[0] + x*res.params.iloc[1]+ res.params.iloc[2]*(x**2)+ res.params.iloc[3]*(x**3)
    plt.plot(x, y, color='red')
